# %%
# Quick sanity check that all libraries import correctly.
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

print(f"pandas version: {pd.__version__}")
print(f"matplotlib version: {plt.matplotlib.__version__}")

# Small DataFrame to verify pandas works
df = pd.DataFrame({
    "restaurant": ["Café 203", "Le Neuvième Art", "Daniel et Denise"],
    "rating": [4.2, 4.8, 4.5],
})
df
# Out:
# pandas version: 2.3.3
# matplotlib version: 3.10.9
#          restaurant  rating
# 0          Café 203     4.2
# 1   Le Neuvième Art     4.8
# 2  Daniel et Denise     4.5
